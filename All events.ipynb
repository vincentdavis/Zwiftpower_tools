# %% [markdown]
# Run this to make sure you have everything you need installed

# %%
#@title
# Install requirements
# This is run just to make sure we have enterything we need.
# !pip install requests
# !pip install bs4
# !pip install pandas>=1.0
# !pip install Pillow
# !pip install plotly
# !pip install chart_studio
# !pip install wget
# !pip install httpimport
# Out:
# Requirement already satisfied: requests in ./venv/lib/python3.8/site-packages (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./venv/lib/python3.8/site-packages (from requests) (1.25.7)
# Requirement already satisfied: idna<2.9,>=2.5 in ./venv/lib/python3.8/site-packages (from requests) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./venv/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.8/site-packages (from requests) (2019.11.28)
# Requirement already satisfied: bs4 in ./venv/lib/python3.8/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.8/site-packages (from bs4) (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in ./venv/lib/python3.8/site-packages (from beautifulsoup4->bs4) (1.9.5)
# Requirement already satisfied: Pillow in ./venv/lib/python3.8/site-packages (7.0.0)
# Requirement already satisfied: plotly in ./venv/lib/python3.8/site-packages (4.4.1)
# Requirement already satisfied: six in ./venv/lib/python3.8/site-packages (from plotly) (1.13.0)
# Requirement already satisfied: retrying>=1.3.3 in ./venv/lib/python3.8/site-packages (from plotly) (1.3.3)
# Requirement already satisfied: chart_studio in ./venv/lib/python3.8/site-packages (1.0.0)
# Requirement already satisfied: retrying>=1.3.3 in ./venv/lib/python3.8/site-packages (from chart_studio) (1.3.3)
# Requirement already satisfied: plotly in ./venv/lib/python3.8/site-packages (from chart_studio) (4.4.1)
# Requirement already satisfied: six in ./venv/lib/python3.8/site-packages (from chart_studio) (1.13.0)
# Requirement already satisfied: requests in ./venv/lib/python3.8/site-packages (from chart_studio) (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./venv/lib/python3.8/site-packages (from requests->chart_studio) (1.25.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.8/site-packages (from requests->chart_studio) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./venv/lib/python3.8/site-packages (from requests->chart_studio) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in ./venv/lib/python3.8/site-packages (from requests->chart_studio) (2.8)
# Requirement already satisfied: wget in ./venv/lib/python3.8/site-packages (3.2)
# Requirement already satisfied: httpimport in ./venv/lib/python3.8/site-packages (0.7.2)

# %% [markdown]
# **Import Python requirments:**
#
# Most importantly:
# [zp_tools](https://github.com/Heteroskedastic/Zwiftpower_tools) from github

# %%
# %load_ext autoreload
# %autoreload 2
import requests
import pandas as pd
import time
from os import path
if path.exists("zp_tools.py"):
  import zp_tools as zpt
else:
    import httpimport
    with httpimport.remote_repo(['zp_tools'], 'https://raw.githubusercontent.com/Heteroskedastic/Zwiftpower_tools/master'):
        import zp_tools as zpt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'}
s=requests.Session()
#url = f'https://zwiftpower.com/api3.php?do=zwift_event_list&_=1581097657241'
url = f'https://zwiftpower.com/api3.php?do=zwift_event_list_results&_=1581097962552'
event_list = s.get(url, headers=headers)
zp_event_list = pd.DataFrame(event_list.json()['data'])

# %%
for c in zp_event_list.columns:
    print(c)
# Out:
# DT_RowId
# friends
# tent
# f_list
# tent_list
# km
# tm
# r
# t
# zid
# rid
# spi
# spl
# f
# zcl
# rt
# layout
# layout_w
# rk
# laps
# cats
# signups
# stag
# w
# dur
# dir
# f_t
# f_km
# f_time
# f_day
# f_w
# f_ru
# f_r
# rtype
# eid
# rules
# crules
# cul
# fin
# ctype
# tags
# recur
# lbl
# qual
# qualt

# %%
zp_event_list.head()
# Out:
#   DT_RowId  friends  tent f_list tent_list     km          tm    r  \
# 0   315973        0     0     []        []  32738  1580839200  314
# 1   315973        0     0     []        []  16507  1580839260  314
# 2   316018        0     0     []        []   5000  1580839200   39
# 3   323247        0     0     []        []      0  1580839200   23
# 4   323248        0     0     []        []  48100  1580839200  107
#
#                                                    t     zid  ... rules  \
# 0                  Tour de Zwift: Stage 6 Group Ride  315973  ...   332
# 1                  Tour de Zwift: Stage 6 Group Ride  315973  ...   332
# 2                   Tour de Zwift: Stage 6 Group Run  316018  ...   320
# 3                                      Uphill Battle  323247  ...   256
# 4  ZRG Winter Race Series 4/10 - Crit Queen&#039;...  323248  ...    68
#
#   crules cul  fin  ctype tags  \
# 0      0   4  315      0
# 1      0   4  315      0
# 2      0   2   40      0
# 3      0   2   24      0
# 4    256   3  125      1
#
#                                                recur lbl  qual qualt
# 0  {'zid1': '315973', 'zid': '315451', 'name': 'T...   1   NaN   NaN
# 1  {'zid1': '315973', 'zid': '315451', 'name': 'T...   2   NaN   NaN
# 2  {'zid1': '316018', 'zid': '315526', 'name': 'T...   0   NaN   NaN
# 3  {'zid1': '323247', 'zid': '316211', 'name': 'U...   0   NaN   NaN
# 4  {'zid1': '323248', 'zid': '310920', 'name': 'Z...   0   NaN   NaN
#
# [5 rows x 45 columns]
